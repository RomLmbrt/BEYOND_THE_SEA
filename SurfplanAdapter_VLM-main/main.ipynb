# %% [markdown]
# # Import a `.txt` SurfPlan file, then create an `Aerosandbox.Airplane` object

# %% [markdown]
# ## Import

# %%
import os
from pathlib import Path
from src.VLM.SPadapter_for_VLM import read_surfplan_txt_vlm

# %% [markdown]
# ## create an `Aerosandbox.Airplane` from a `.txt` SurfPlan file

# %%
# Find the root directory of the repository
root_dir = os.path.abspath(os.getcwd())

# Example usage:
# filepath = Path(root_dir) / "data" / "TUDELFT_V3_LEI_KITE" / "V3D_3d.txt"
filepath = Path(root_dir)/ "data" / "BEYOND_THE_SEA" / "SK50-VH_3d.txt"


# filepath = 'data/Seakite50_VH/SK50-VH_3d.txt'
airplane = read_surfplan_txt_vlm(filepath)
airplane.draw_three_view()
# Out:
# array([[<Axes3D: zlabel='$z_g$ [m]'>, <Axes3D: >],
#        [<Axes3D: xlabel='$x_g$ [m]', ylabel='$y_g$ [m]'>, <Axes3D: >]],
#       dtype=object)
