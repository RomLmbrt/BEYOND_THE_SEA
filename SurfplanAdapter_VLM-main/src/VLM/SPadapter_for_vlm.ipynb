# %%
import numpy as np
import os
from pathlib import Path
import aerosandbox as asb
from SurfplanAdapter.surfplan_to_vsm.read_profile_from_airfoil_dat_files import (
    reading_profile_from_airfoil_dat_files,
)

def read_surfplan_txt_vlm(filepath):
    """
    Read the main characteristics of kite ribs and LE (Leading Edge) tube sections from the .txt file from Surfplan.

    Parameters:
    filepath (str): The name of the file containing the 3D rib and LE tube data.

    Returns:
        An Aerosandbox Airplane object.
    """
    with open(filepath, "r") as file:
        lines = file.readlines()
        
    with open(filepath, "r") as file:
        lines = file.readlines()

    ribs_data = []  # Output list to store the ribs' data
    ribs = (
        []
    )  # List to store rib data: [LE position [x,y,z], TE position [x,y,z], Up vector VUP [x,y,z]]
    le_tube = []  # List to store diameters of the LE tube sections
    n_ribs = 0  # Number of ribs
    n_le_sections = 0  # Number of LE sections
    txt_section = None  # Current section being read ('ribs' or 'le_tube')
    mainwing_xsecs = []

    for line in lines:
        line = line.strip()
        if line.startswith("3d rib positions"):
            txt_section = "ribs"
            continue
        elif line.startswith("LE tube"):
            txt_section = "le_tube"
            continue

        # Read kite ribs and store data in ribs
        if txt_section == "ribs":
            if not line:  # Empty line indicates the end of the section
                txt_section = None
                continue
            if not any(char.isdigit() for char in line):
                continue  # Skip comment lines
            if line.isdigit():
                n_ribs = int(line)
                continue
            values = list(map(float, line.split(",")))
            if len(values) == 9:
                le = np.array(values[0:3])  # Leading edge position
                te = np.array(values[3:6])  # Trailing edge position
                vup = np.array(values[6:9])  # Up vector
                ribs.append([le, te, vup])
        # Read Kite LE tube and store data in le_tube
        elif txt_section == "le_tube":
            if not line:  # Empty line indicates the end of the section
                txt_section = None
                continue
            if not any(char.isdigit() for char in line):
                continue  # Skip comment lines
            if line.isdigit():
                n_le_sections = int(line)
                continue
            values = list(map(float, line.split(",")))
            if len(values) == 4:
                # centre = np.array(values[0:3])  #centre position [x,y,y] of the LE tube section
                diameter = values[3]  # Diameter of the LE tube section
                # le_tube.append([centre, diam])
                le_tube.append(diameter)

    # LE tube sections list is bigger than ribs list because the wingtip are decomposed of more LE section than ribs
    # We remove wingtips sections from LE tube sections list to make LE and rib lists the same size
    wingtip_size = int((n_le_sections - n_ribs) / 2)
    le_tube = le_tube[wingtip_size:-wingtip_size]

    for i in range(n_ribs):
        # Rib position
        rib_le = ribs[i][0]
        rib_te = ribs[i][1]
        # Tube diameter
        # normalize tube diameter with local chord
        tube_diameter = le_tube[i] / np.linalg.norm(rib_te - rib_le)
        # Associate each rib with its airfoil .dat file name
        k = n_ribs // 2
        # First case, kite has one central rib
        if n_ribs % 2 == 1:
            # print(1 +abs(k-i))
            profile_name = f"rib_{1 +abs(-k+i)}.dat"
        # Second case, kite has two central ribs
        else:
            if i < k:
                # print(k-i)
                profile_name = f"rib_{k-i}.dat"
            else:
                # print(i-k+1)
                profile_name = f"rib_{i-k+1}.dat"
        # Extract the directory path
        airfoil_directory_path = os.path.dirname(filepath) + "/profiles/" + profile_name
        # Read camber height from .dat airfoil file

        # It's possible to add here more airfoil parameters to read in the dat file for more complete airfoil data
        # x_camber = airfoil["x_depth"]
        # TE_angle = airfoil["TE_angle"]
        chord = np.linalg.norm(rib_te - rib_le)
        twist = np.atan((rib_le[1]-rib_te[1])/(rib_le[2]-rib_te[2]))*180/np.pi

        xsec = asb.WingXSec(
            xyz_le=rib_le,
            chord=chord,
            twist=twist,
            airfoil=airfoil_directory_path,
        )
        mainwing_xsecs.append(xsec)
    
        mainwing_name = str(filepath).split("/")[-1].split(".")[0]

        mainwing = asb.Wing(
            name=mainwing_name,
            xsecs=mainwing_xsecs,
            symmetric=False,
            is_main_wing=True,
            is_horizontal_stabilizer=False,
            is_vertical_stabilizer=False,
            is_fuselage=False,
        )
        airplane = asb.Airplane(
            name=mainwing.name,
            xyz_ref=[0,0,0],
            wings=[mainwing],
        )

    return airplane  # , df_section


if __name__ == "__main__":
    # Find the root directory of the repository
    root_dir = os.path.abspath(os.getcwd())

    # Example usage:
    filepath = Path(root_dir)/".."/".." / "data" / "TUDELFT_V3_LEI_KITE" / "V3D_3d_copy.txt"

    # filepath = 'data/Seakite50_VH/SK50-VH_3d.txt'
    ribs_data = read_surfplan_txt_vlm(filepath)
    for rib in ribs_data:
        print(rib)
        # print("\n")
        # print(rib["d_tube"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 149
#     146 filepath = Path(root_dir)/".."/".." / "data" / "TUDELFT_V3_LEI_KITE" / "V3D_3d_copy.txt"
#     148 # filepath = 'data/Seakite50_VH/SK50-VH_3d.txt'
# --> 149 ribs_data = read_surfplan_txt_vlm(filepath)
#     150 for rib in ribs_data:
#     151     print(rib)
#
# Cell In[5], line 132, in read_surfplan_txt_vlm(filepath)
#     121     mainwing_name = str(filepath).split("/")[-1].split(".")[0]
#     123     mainwing = asb.Wing(
#     124         name=mainwing_name,
#     125         xsecs=mainwing_xsecs,
#    (...)
#     130         is_fuselage=False,
#     131     )
# --> 132     airplane = asb.Airplane(
#     133         name=mainwing.name,
#     134         xyz_ref=[0,0,0],
#     135         wings=[mainwing],
#     136     )
#     138 return airplane
#
# File c:\Users\RomainLambert\AppData\Local\Programs\Python\Python312\Lib\site-packages\aerosandbox\geometry\airplane.py:123, in Airplane.__init__(self, name, xyz_ref, wings, fuselages, propulsors, s_ref, c_ref, b_ref, analysis_specific_options)
#     121 else:
#     122     if main_wing is not None:
# --> 123         self.s_ref = main_wing.area()
#     124     else:
#     125         if main_fuse is not None:
#
# File c:\Users\RomainLambert\AppData\Local\Programs\Python\Python312\Lib\site-packages\aerosandbox\geometry\wing.py:352, in Wing.area(self, type, include_centerline_distance, _sectional)
#     349 # Compute sectional areas. Each method must compute the sectional spans and the effective chords at each
#     350 # cross-section to use.
#     351 if type == "planform":
# --> 352     sectional_spans = self.span(type="yz", _sectional=True)
#     353     xsec_chords = [xsec.chord for xsec in self.xsecs]
#     355 elif type == "wetted":
#
# File c:\Users\RomainLambert\AppData\Local\Programs\Python\Python312\Lib\site-packages\aerosandbox\geometry\wing.py:213, in Wing.span(self, type, include_centerline_distance, _sectional)
#     209 # Figure out where the quarter-chord points of each WingXSec are
#     210 i_range = range(len(self.xsecs))
#     212 quarter_chord_locations = [
# --> 213     self._compute_xyz_of_WingXSec(
#     214         i,
#     215         x_nondim=0.25,
#     216         z_nondim=0,
#     217     )
#     218     for i in i_range
#     219 ]
#     221 # Compute sectional spans
#     222 sectional_spans = []
#
# File c:\Users\RomainLambert\AppData\Local\Programs\Python\Python312\Lib\site-packages\aerosandbox\geometry\wing.py:1312, in Wing._compute_xyz_of_WingXSec(self, index, x_nondim, z_nondim)
#    1306 def _compute_xyz_of_WingXSec(
#    1307     self,
#    1308     index,
#    1309     x_nondim,
#    1310     z_nondim,
#    1311 ):
# -> 1312     xg_local, yg_local, zg_local = self._compute_frame_of_WingXSec(index)
#    1313     origin = self.xsecs[index].xyz_le
#    1314     xsec = self.xsecs[index]
#
# File c:\Users\RomainLambert\AppData\Local\Programs\Python\Python312\Lib\site-packages\aerosandbox\geometry\wing.py:1344, in Wing._compute_frame_of_WingXSec(self, index)
#    1341 xg_local = np.array([1, 0, 0])
#    1342 if index == 0:
#    1343     yg_local = project_to_YZ_plane_and_normalize(
# -> 1344         self.xsecs[1].xyz_le - self.xsecs[0].xyz_le
#    1345     )
#    1346     z_scale = 1
#    1347 elif index == len(self.xsecs) - 1 or index == -1:
#
# IndexError: list index out of range
